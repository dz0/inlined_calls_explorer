# %%
# data  fragments from interim/2017/05/tab.csv

csv = """
	Год / Year	Кварталы / Quarters			
		I	II	III	IV
1. Сводные показатели / Aggregated indicators					
1.1. Валовой внутренний продукт1) / Gross domestic product1)					
Объем ВВП, млрд.рублей /GDP, bln rubles					
20152)	83233	18568	19858	21967	22840
20162)	86044	18816	20430	22721	24077
2017		200913)			

Год / Year	Кварталы / Quarters	Янв. Jan.	Фев. Feb.	Март Mar.	Апр. Apr.	Май May	Июнь June	Июль July	Август Aug.	Сент. Sept.	Окт. Oct.	Нояб. Nov.	Дек. Dec.			
		I	II	III	IV												
1.2. Индекс промышленного производства1) / Industrial Production index1)																	
Индекс промышленного производства, 
в % к соответствующему периоду предыдущего года / percent of corresponding period of previous year																	
2015	99,2	99,9	98,3	99,5	99,1	100,0	98,2	101,2	98,2	97,6	99,1	98,5	100,2	99,7	98,4	101,0	98,1
2016	101,3	101,1	101,5	101,0	101,7	99,2	103,8	100,3	101,0	101,5	102,0	101,4	101,5	100,1	101,6	103,4	100,2
2017		100,1				102,3	97,3	100,8	102,3	105,6							
в % к предыдущему периоду / percent of previous period																	
2015		82,8	102,6	103,9	112,3	73,9	99,8	112,5	95,6	97,6	103,2	100,5	101,4	103,1	105,0	101,9	109,1
2016		84,4	103,1	103,3	113,1	74,7	104,4	108,8	96,3	98,1	103,8	99,9	101,5	101,7	106,6	103,6	105,8
2017		83,1				76,2	99,4	112,7	97,7	101,2							
период с начала отчетного года в % к соответствующему периоду предыдущего года / period from beginning of reporting year as percent of corresponding period of previous year																	
2015						100,0	99,1	99,9	99,4	99,1	99,1	99,0	99,1	99,2	99,1	99,3	99,2
2016						99,2	101,5	101,1	101,1	101,1	101,3	101,3	101,3	101,2	101,2	101,4	101,3
2017						102,3	99,7	100,1	100,7	101,7							
	Янв. Jan.	Фев. Feb.	Март Mar.	Апр. Apr.	Май May	Июнь June	Июль July	Август Aug.	Сент. Sept.	Окт. Oct.	Нояб. Nov.	Дек. Dec.
1.2.1. Индексы производства по видам деятельности1) (без исключения сезонности и фактора времени) / Industrial Production indices by Industry (without seasonal and time factor adjustment)												
"""

# %%
import pandas as pd

from csv2df.specification import Definition, Specification, SPEC
from csv2df.reader import Reader, open_csv
from csv2df.parser import extract_tables
from csv2df.emitter import Emitter

def get_dataframes(csvfile, spec=SPEC):
    tables = [t for csv_segment, pdef in Reader(csvfile, spec).items()
              for t in extract_tables(csv_segment, pdef)]
    # print(list(tables))
    
    emitter = Emitter(tables)
    dfa = emitter.get_dataframe(freq='a')
    dfq = emitter.get_dataframe(freq='q')
    dfm = emitter.get_dataframe(freq='m')
    return dfa, dfq, dfm

main = Definition(units={
                        'млрд.рублей': 'bln_rub', 
                        'период с начала отчетного года в % к соответствующему периоду предыдущего года': 'ytd',
                        'в % к соответствующему периоду предыдущего года': 'yoy',
                        'в % к предыдущему периоду': 'rog'
                        })

main.append(varname='GDP',
            text='Объем ВВП',
            required_units=['bln_rub'])

main.append(varname="INDPRO",
            text="Индекс промышленного производства",
            required_units=["yoy", "rog"],
            desc="Промышленное производство")


spec1 = Specification(default=main)

import io
csvfile1 = io.StringIO(csv )

# %%
from mytracer import trace_calls

# %%
import sys
sys.settrace(trace_calls)
dfa1, dfq1, dfm1 = get_dataframes(csvfile1, spec1)
# Out:
# CALL     def __init__(self, csvfile, spec):
#
# CALL def to_rows(csvfile):
#
# CALL def filter_csv_rows(gen):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     filled = filter(lambda row: row and row[0], gen)
#
# CALL     no_comments = filter(lambda row: not row[0].startswith("___"), filled)
#
# CALL     def __init__(self, row):
#
# CALL def yield_csv_rows(csvfile, fmt=CSV_FORMAT):
#
# CALL     def items(self):
#
# CALL     def __init__(self, rows):
#
# CALL     def yield_segment_with_defintion(self, spec):
#
# CALL     def get_segment_parsing_definitions(self):
#
# CALL     def remaining_rows(self):
#
# CALL     def get_main_parsing_definition(self):
#
# CALL def extract_tables(csv_segment, pdef):
#
# CALL def parse_tables(tables, pdef):
#
# CALL def parse_tables(tables, pdef):
#
# CALL def split_to_tables(rows):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     @property
#
# CALL     @property
#
# CALL     def set_label(self, varnames_dict, units_dict):
#
# CALL     def get_varname(self, varnames_mapper_dict):
#
# CALL     def matches(self, pat):
#
# CALL     def matches(self, pat):
#
# CALL     def get_unit(self, units_mapper_dict):
#
# CALL     def get_varname(self, varnames_mapper_dict):
#
# CALL     def matches(self, pat):
#
# CALL     def matches(self, pat):
#
# CALL     def get_unit(self, units_mapper_dict):
#
# CALL     def get_varname(self, varnames_mapper_dict):
#
# CALL     def matches(self, pat):
#
# CALL     def matches(self, pat):
#
# CALL     def get_unit(self, units_mapper_dict):
#
# CALL def split_to_tables(rows):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     @property
#
# CALL     @property
#
# CALL     def set_label(self, varnames_dict, units_dict):
#
# CALL     def get_varname(self, varnames_mapper_dict):
#
# CALL     def matches(self, pat):
#
# CALL     def matches(self, pat):
#
# CALL     def get_unit(self, units_mapper_dict):
#
# CALL     def get_varname(self, varnames_mapper_dict):
#
# CALL     def matches(self, pat):
#
# CALL     def matches(self, pat):
#
# CALL     def get_unit(self, units_mapper_dict):
# CALL     def get_varname(self, varnames_mapper_dict):
#
# CALL     def matches(self, pat):
#
# CALL     def matches(self, pat):
#
# CALL     def get_unit(self, units_mapper_dict):
#
# CALL     def get_varname(self, varnames_mapper_dict):
#
# CALL     def matches(self, pat):
#
# CALL     def matches(self, pat):
#
# CALL     def get_unit(self, units_mapper_dict):
#
# CALL def split_to_tables(rows):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     @property
#
# CALL     @property
#
# CALL     def set_label(self, varnames_dict, units_dict):
#
# CALL     def get_varname(self, varnames_mapper_dict):
#
# CALL     def matches(self, pat):
#
# CALL     def matches(self, pat):
#
# CALL     def get_unit(self, units_mapper_dict):
#
# CALL def split_to_tables(rows):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def is_datarow(self):
#
# CALL def is_year(string: str) -> bool:
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     def __len__(self):
#
# CALL     def __init__(self, headers, datarows):
#
# CALL     @property
#
# CALL     @property
#
# CALL     def set_label(self, varnames_dict, units_dict):
#
# CALL     def get_varname(self, varnames_mapper_dict):
#
# CALL     def matches(self, pat):
#
# CALL     def matches(self, pat):
#
# CALL     def get_unit(self, units_mapper_dict):
#
# CALL def split_to_tables(rows):
#
# CALL def parse_tables(tables, pdef):
#
# CALL     @property
#
# CALL     def set_splitter(self, funcname):
#
# CALL def get_splitter(arg):
#
# CALL     @property
#
# CALL     def set_splitter(self, funcname):
#
# CALL def get_splitter(arg):
#
# CALL     @property
#
# CALL     def set_splitter(self, funcname):
#
# CALL def get_splitter(arg):
#
# CALL     @property
#
# CALL     def set_splitter(self, funcname):
#
# CALL def get_splitter(arg):
#
# CALL     def fix_multitable_units(tables):
#
# CALL     def has_unknown_lines(self):
#
# CALL     def has_unknown_lines(self):
#
# CALL def verify_tables(tables, pdef):
#
# CALL def verify_tables(tables, pdef):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     @property
#
# CALL def verify_tables(tables, pdef):
#
# CALL def extract_tables(csv_segment, pdef):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     @property
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     @property
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     @property
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     @property
#
# CALL     def yield_segment_with_defintion(self, spec):
#
# CALL     def __init__(self, tables):
#
# CALL     @staticmethod
#
# CALL     def is_defined(self):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def _import(self, table):
#
# CALL     def get_year(self):
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def __init__(self, year, label):
#
# CALL def split_row_by_year_and_qtr(row):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def get_year(self):
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def __init__(self, year, label):
#
# CALL def split_row_by_year_and_qtr(row):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def get_year(self):
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def __init__(self, year, label):
#
# CALL def split_row_by_year_and_qtr(row):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     @staticmethod
#
# CALL     def is_defined(self):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def _import(self, table):
#
# CALL     def get_year(self):
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def __init__(self, year, label):
#
# CALL def split_row_by_periods(row):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def get_year(self):
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def __init__(self, year, label):
#
# CALL def split_row_by_periods(row):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def get_year(self):
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def __init__(self, year, label):
#
# CALL def split_row_by_periods(row):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     @staticmethod
#
# CALL     def is_defined(self):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def _import(self, table):
#
# CALL     def get_year(self):
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def __init__(self, year, label):
#
# CALL def split_row_by_periods(row):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def get_year(self):
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def __init__(self, year, label):
#
# CALL def split_row_by_periods(row):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def get_year(self):
#
# CALL def get_year(string: str, rx=YEAR_CATCHER):
#
# CALL     @property
#
# CALL def make_label(vn, unit, sep=SEP):
#
# CALL     def __init__(self, year, label):
#
# CALL def split_row_by_periods(row):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def _import(self, table):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def make(self, freq: str, x: float, period=False):
#
# CALL     def set_value(self, x):
#
# CALL def to_float(text: str, i=0):
#
# CALL     def as_dict(self):
#
# CALL     def get_date(self):
#
# CALL     def get_dataframe(self, freq):
#
# CALL     def _collect(self, freq):
#
# !!!         df = pd.DataFrame(self._collect(freq)) # TRACE: freq, df.loc[:3]
#
# inspect STACK
#
# -> <ipython-input-4-c1e739101db9>:4:<module>: sys.settrace(trace_calls)
#   -> <ipython-input-2-e6621449485e>:15:get_dataframes:     emitter = Emitter(tables)
#     -> /home/jurgis/dev/Freelancer/mini-kep/src/csv2df/emitter.py:149:get_dataframe:         df = pd.DataFrame(self._collect(freq)) # TRACE: freq, df.loc[:3]
#
# TRACEVAR: freq a
# TRACEVAR: df.loc[:3]   freq        label time_index    value  year
# 0    a  GDP_bln_rub 2015-12-31  83233.0  2015
# 1    a  GDP_bln_rub 2016-12-31  86044.0  2016
# 2    a   INDPRO_yoy 2015-12-31     99.2  2015
# 3    a   INDPRO_yoy 2016-12-31    101.3  2016
# CALL     @staticmethod
#
# CALL     def get_dataframe(self, freq):
#
# CALL     def _collect(self, freq):
#
# !!!         df = pd.DataFrame(self._collect(freq)) # TRACE: freq, df.loc[:3]
#
# inspect STACK
#
# -> <ipython-input-4-c1e739101db9>:4:<module>: sys.settrace(trace_calls)
#   -> <ipython-input-2-e6621449485e>:16:get_dataframes:     dfa = emitter.get_dataframe(freq='a')
#     -> /home/jurgis/dev/Freelancer/mini-kep/src/csv2df/emitter.py:149:get_dataframe:         df = pd.DataFrame(self._collect(freq)) # TRACE: freq, df.loc[:3]
#
# TRACEVAR: freq q
# TRACEVAR: df.loc[:3]   freq        label  qtr time_index    value  year
# 0    q  GDP_bln_rub    1 2015-03-31  18568.0  2015
# 1    q  GDP_bln_rub    2 2015-06-30  19858.0  2015
# 2    q  GDP_bln_rub    3 2015-09-30  21967.0  2015
# 3    q  GDP_bln_rub    4 2015-12-31  22840.0  2015
# CALL     @staticmethod
#
# CALL     def get_dataframe(self, freq):
#
# CALL     def _collect(self, freq):
#
# !!!         df = pd.DataFrame(self._collect(freq)) # TRACE: freq, df.loc[:3]
#
# inspect STACK
#
# -> <ipython-input-4-c1e739101db9>:4:<module>: sys.settrace(trace_calls)
#   -> <ipython-input-2-e6621449485e>:17:get_dataframes:     dfq = emitter.get_dataframe(freq='q')
#     -> /home/jurgis/dev/Freelancer/mini-kep/src/csv2df/emitter.py:149:get_dataframe:         df = pd.DataFrame(self._collect(freq)) # TRACE: freq, df.loc[:3]
#
# TRACEVAR: freq m
# TRACEVAR: df.loc[:3]   freq       label  month time_index  value  year
# 0    m  INDPRO_yoy      1 2015-01-31  100.0  2015
# 1    m  INDPRO_yoy      2 2015-02-28   98.2  2015
# 2    m  INDPRO_yoy      3 2015-03-31  101.2  2015
# 3    m  INDPRO_yoy      4 2015-04-30   98.2  2015
# CALL     @staticmethod

# %%
dfa1
# Out:
#             year  GDP_bln_rub  INDPRO_yoy
# time_index
# 2015-12-31  2015      83233.0        99.2
# 2016-12-31  2016      86044.0       101.3

# %%
print( dfa1 )
# Out:
#             year  GDP_bln_rub  INDPRO_yoy
# time_index
# 2015-12-31  2015      83233.0        99.2
# 2016-12-31  2016      86044.0       101.3
